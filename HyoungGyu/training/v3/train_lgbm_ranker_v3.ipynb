# %% [markdown]
# # LightGBM Ranker v3
#
# Runs `train_lgbm_ranker_v3.py` and writes artifacts to `artifacts/`.
#
# Main changes vs v2:
# - averages four LightGBM rankers with different seeds/hyperparameters.
# - keeps v2 op/value rules unchanged.
# - targets better `target_id` accuracy.

# %%
from pathlib import Path
import runpy

candidates = [
    Path('train_lgbm_ranker_v3.py'),
    Path('HyoungGyu/training/v3/train_lgbm_ranker_v3.py'),
]
script_path = next((p for p in candidates if p.exists()), None)
if script_path is None:
    raise FileNotFoundError('train_lgbm_ranker_v3.py not found. Run this notebook from v3/ or project root.')

runpy.run_path(str(script_path), run_name='__main__')
